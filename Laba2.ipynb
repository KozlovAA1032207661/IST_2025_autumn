# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
name = "Тигры.jpg"
img = Image.open(name)
img_array = np.array(img, dtype=np.float32)

plt.figure(figsize=(10,7))
plt.imshow(img)
plt.title(f"Изображение тигренка ({img.width}×{img.height})")
plt.axis('off')
plt.show()

print(f"Размер массива: {img_array.shape}, диапазон значений: {img_array.min():.1f}–{img_array.max():.1f}")
# Out:
# Размер массива: (1080, 1920, 3), диапазон значений: 0.0–255.0

# %%
U_R, S_R, Vt_R = np.linalg.svd(img_array[:, :, 0], full_matrices=False)
U_G, S_G, Vt_G = np.linalg.svd(img_array[:, :, 1], full_matrices=False)
U_B, S_B, Vt_B = np.linalg.svd(img_array[:, :, 2], full_matrices=False)

print(f"U: {U_R.shape}, S: {S_R.shape}, Vt: {Vt_R.shape}, сингулярных значений: {len(S_R)}")
# Out:
# U: (1080, 1080), S: (1080,), Vt: (1080, 1920), сингулярных значений: 1080

# %%
def reconstruct_image(U, S, Vt, k):
    U_k = U[:, :k]
    S_k = np.diag(S[:k])
    Vt_k = Vt[:k, :]
    rec = U_k @ S_k @ Vt_k
    rec = np.clip(rec, 0, 255)
    return rec.astype(np.uint8)

# %%
m, n = img_array.shape[:2]
max_k = min(m, n)
k_values = [1, 2, 10, 30, 100, max_k]

results = {}

for k in k_values:
    reconstructed = np.stack([
        reconstruct_image(U_R, S_R, Vt_R, k),
        reconstruct_image(U_G, S_G, Vt_G, k),
        reconstruct_image(U_B, S_B, Vt_B, k)
    ], axis=2)

    compressed_elements = 3 * (m * k + k + k * n)
    compression_ratio = (3*m*n)/compressed_elements if k!=max_k else 1.0
    mse = 0 if k==max_k else np.mean(((img_array/255)-(reconstructed/255))**2)

    results[k] = (reconstructed, compression_ratio, mse)

# %%
plt.figure(figsize=(18,10))

for i,k in enumerate(k_values):
    img_rec, ratio, mse = results[k]
    plt.subplot(2,3,i+1)
    plt.imshow(img_rec)
    plt.axis('off')
    if k==max_k:
        plt.title(f"Исходное изображение (k={k})")
    else:
        plt.title(f"k={k}, {ratio:.1f}:1, MSE={mse:.4f}")

plt.suptitle("Сжатие изображения с помощью SVD", fontsize=16)
plt.tight_layout()
plt.show()

# %%
print("=" * 85)
# -------------------------------
# ВЫВОДЫ ПО ЛАБОРАТОРНОЙ РАБОТЕ
# -------------------------------

print("\nВЫВОДЫ")
print("=" * 70)

print("1. В данной работе было реализовано сжатие изображения с потерями "
      "с использованием сингулярного разложения (SVD).")

print("2. Цветное изображение было представлено в виде трёх отдельных каналов "
      "(R, G и B), к каждому из которых SVD применялось независимо.")

print("3. Экспериментально показано, что использование небольшого количества "
      "сингулярных значений позволяет значительно уменьшить объём данных "
      "при сохранении визуального качества изображения.")

print("4. При малых значениях k изображение теряет мелкие детали и становится "
      "размытым, однако его основные структуры и цвета сохраняются.")

print("5. Увеличение числа сингулярных значений приводит к снижению среднеквадратичной "
      "ошибки (MSE) и приближению восстановленного изображения к исходному.")

print("6. Таким образом, метод SVD позволяет эффективно контролировать компромисс "
      "между степенью сжатия изображения и качеством его восстановления.")

print("=" * 70)
# Out:
# ...
#
# ВЫВОДЫ
# ...
# 1. В данной работе было реализовано сжатие изображения с потерями с использованием сингулярного разложения (SVD).
# 2. Цветное изображение было представлено в виде трёх отдельных каналов (R, G и B), к каждому из которых SVD применялось независимо.
# 3. Экспериментально показано, что использование небольшого количества сингулярных значений позволяет значительно уменьшить объём данных при сохранении визуального качества изображения.
# 4. При малых значениях k изображение теряет мелкие детали и становится размытым, однако его основные структуры и цвета сохраняются.
# 5. Увеличение числа сингулярных значений приводит к снижению среднеквадратичной ошибки (MSE) и приближению восстановленного изображения к исходному.
# 6. Таким образом, метод SVD позволяет эффективно контролировать компромисс между степенью сжатия изображения и качеством его восстановления.
# ...
